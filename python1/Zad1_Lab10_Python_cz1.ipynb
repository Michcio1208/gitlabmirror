# %% [markdown]
# # MICHAŁ KRYSTECKI 342906

# %% [markdown]
# # Zadanie 1 - WINF - Laboratorium nr 10 - Python cz. 1
#
# Treść każdego zadania została umieszczona w oddzielnej komórce tekstowej (markdown cell). Rozwiązania proszę umieszczać bezpośrednio pod treścią poleceń wykorzystująć dedykowaną komórkę wykonawczą (code cell). Odpowiedzie na pytania jeżeli są i komentarze do rozwiązania proszę umieścić we włą w dedykowanej komórce tekstowej.
# Jako rozwiązanie proszę zapisać utworzony notebook w z rozszerzeniem .ipynb i umieścić go na serwerze LeON.

# %% [markdown]
# ## Zadanie 1A
# Wykorzystując funkcję `print` języka Python wypisać: symbol znaku oraz jego kod w zapisach dziesiętnym, heksadecymalnym i binarnym dla następujących znaków:
#
# **A, 2, ^, Ą, €, 𝜑**
#
# Sprawdzić, czy kody tych znaków znajdują się w:
# - tabeli ASCII: https://pl.wikipedia.org/wiki/ASCII
# - tabeli znaków Unicode (np. na stronie: www.charset.org)
#
# ## Wskazówki
# - W trakcie realizacji zadania pomocne będą następujące funkcje wbudowane:
#     - `ord()` – zwraca kod znaku (wartość Unicode) w zapisie dziesiętnym
#     - `hex()` – zamienia liczbę na zapis heksadecymalny
#     - `bin()` – zamienia liczbę na zapis binarny
#     - `chr()` – zwraca znak na podstawie podanego kodu Unicode
# - Jeżeli znak jest z zakresu ASCII to również znajdueje się na klawiaturze i wypisanie elementów wydaje się stosunkowo proste.
# - W przypadku znaków spoza zakresu ASCII należy wejść na stronę https://www.charset.org/utf-8 i odnleźć interesujący znak - np. symbol theta ϑ
#    - odczytać jego kod: U+03D1
#    - i np. wykonać polecenia z poniższej komórki:

# %%
# Wypisanie reprezentacji graficznej oraz kodów numerycznych symbolu spoza zakresu ASCII
theta = chr(0x03D1)   # kod znaku theta
print("Znak:", theta)
print("Dziesiętny:", ord(theta))
print("Heksadecymalny:", hex(ord(theta)))
print("Binarny:", bin(ord(theta)))
# Out:
# Znak: ϑ
# Dziesiętny: 977
# Heksadecymalny: 0x3d1
# Binarny: 0b1111010001

# %%
dwa= chr(0x0032)   # kod znaku dwa
print("Znak:", dwa)
print("Dziesiętny:", ord(dwa))
print("Heksadecymalny:", hex(ord(dwa)))
print("Binarny:", bin(ord(dwa)))
# Out:
# Znak: 2
# Dziesiętny: 50
# Heksadecymalny: 0x32
# Binarny: 0b110010

# %%
znak= chr(0x005E)   # kod znaku ^
print("Znak:", znak)
print("Dziesiętny:", ord(znak))
print("Heksadecymalny:", hex(ord(znak)))
print("Binarny:", bin(ord(znak)))
# Out:
# Znak: ^
# Dziesiętny: 94
# Heksadecymalny: 0x5e
# Binarny: 0b1011110

# %%
A= chr(0x0104)   # kod znaku duzej litery A z ogonkiem
print("Znak:", A)
print("Dziesiętny:", ord(A))
print("Heksadecymalny:", hex(ord(A)))
print("Binarny:", bin(ord(A)))
# Out:
# Znak: Ą
# Dziesiętny: 260
# Heksadecymalny: 0x104
# Binarny: 0b100000100

# %%
euro= chr(0x20AC)   # kod znaku euro
print("Znak:", euro)
print("Dziesiętny:", ord(euro))
print("Heksadecymalny:", hex(ord(euro)))
print("Binarny:", bin(ord(euro)))
# Out:
# Znak: €
# Dziesiętny: 8364
# Heksadecymalny: 0x20ac
# Binarny: 0b10000010101100

# %% [markdown]
# # Zadanie 1B
# Proszę wykonać poniższe instrukcje:
# ```python
# print("\u2665")
# print("\U2665")
# print("\U00002665")
# ```
# - Wyjaśnić otrzymywane wyniki. Wskazówka: należy zwrócić uwagę na wielkość litery u i długość argumentu.
# - Posługując się stroną zawierającą wartości kodu UTF - np. https://unicode-table.com/en/ wyświetlić kilka niestandardowych znaków, jak np. symbole walut, symbole figur szachowych
# (Miscalleneous Symbols), znaki emoji.

# %%
print("\u2665")
print("\U2665")
print("\U00002665")
# Out:
#   Cell In[13], line 2
#     print("\U2665")
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-5: truncated \UXXXXXXXX escape

# %%
print("\u2665")
print("\U00002665")
# Out:
# ♥
# ♥

# %% [markdown]
# # Odpowiedź
# Po znaku "u" python oczekuje 4 cyfr, a po znaku "U" oczekuje 8 cyfr. Dlatego po wpisaniu komendy dla "\U2665" otrzymujemy błąd

# %% [markdown]
# # Zadanie 1C
# Proszę zdefiniować zmienną napisową zawierającą pangram:
# ```python
# napis = "Pchnąć w tę łódź jeża lub ośm skrzyń fig"
# ```
# Dla utworzonej w zmiennej napis:
# - za pomocą operatora `[index]` i operatora konkatencji `+` z liter zmiennej utworzyć zmienną napisową zawierającą słowo Python
# - za pomocą operatora`[index1:index2]` z liter zmiennej utworzyć dwie zmienne napisowe zawierające rzeczowniki występujące w tej zmiennej
# - za pomocą funkcji `len()` znaleźć długość zmiennej
# - za pomocą metody `index()` znaleźć pozycję słowa łódź
# - za pomocą odpowiedniej metody zmienić wszystkie litery na duże
#
# W razie potrzeby informacje (np. nazwy metod służących do manipulacji zmiennymi napisowymi
# można znaleźć za pomocą komendy:
# ```python
# help(str)
# ```

# %%
napis="Pchnąć w tę łódź jeża lub ośm skrzyń fig"
print(napis[0]+napis[-6]+napis[9]+napis[2]+napis[-14]+napis[3])
# Out:
# Python

# %%
napis="Pchnąć w tę łódź jeża lub ośm skrzyń fig"
lodzjez=napis[12:16]+" "+napis[17:21]
skrzyniafig=napis[30:36]+" "+napis[-3:]
print(lodzjez + " " + skrzyniafig)
# Out:
# łódź jeża skrzyń fig

# %%
napis="Pchnąć w tę łódź jeża lub ośm skrzyń fig"
print("Długość napisu to :",len(napis))
# Out:
# Długość napisu to : 40

# %%
napis="Pchnąć w tę łódź jeża lub ośm skrzyń fig"
print("pozycja słowa \"łódź\" to indeksy pomiędzy:", napis.index("ł"),"a",napis.index("ź")+1)
print(napis[napis.index("ł"):napis.index("ź")+1])
# Out:
# pozycja słowa "łódź" to indeksy pomiędzy: 12 a 16
# łódź

# %%
napis="Pchnąć w tę łódź jeża lub ośm skrzyń fig"
napis=napis.upper()
print(napis)
# Out:
# PCHNĄĆ W TĘ ŁÓDŹ JEŻA LUB OŚM SKRZYŃ FIG
